# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = [12, 9, 8, 14, 15, 11, 10, 15]
y = [42, 107, 100, 60, 78, 79, 90, 54]

X = sm.add_constant(X)
model = sm.regression.linear_model.OLS(y, X)
results = model.fit()
print(results.summary())

mean_x = np.mean(X)
mean_y = np.mean(y)


y_pred = results.predict(X)

SSregression = ((y_pred - mean_y) ** 2).sum()
SStotal = ((y - mean_y) ** 2).sum()
r2 = SSregression / SStotal
print (r2)

# %%
X = sm.add_constant(X)
model = sm.regression.linear_model.OLS(y, X)
results = model.fit()
print(results.summary())

mean_x = np.mean(X)
mean_y = np.mean(y)


y_pred = results.predict(X)

SSregression = ((y_pred - mean_y) ** 2).sum()
SStotal = ((y - mean_y) ** 2).sum()
r2 = SSregression / SStotal
print (r2)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.517
# Model:                            OLS   Adj. R-squared:                  0.437
# Method:                 Least Squares   F-statistic:                     6.433
# Date:                Thu, 28 Nov 2024   Prob (F-statistic):             0.0443
# Time:                        20:15:37   Log-Likelihood:                -32.920
# No. Observations:                   8   AIC:                             69.84
# Df Residuals:                       6   BIC:                             70.00
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        147.3204     28.667      5.139      0.002      77.174     217.467
# ...

# %%
mean_x = np.mean(X)
mean_y = np.mean(y)
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
4 # Calculate the mean of the dependent variable

# Calculate SSregression and SStotal to get R-squared
SSregression = ((y_pred - mean_y) ** 2).sum()
SStotal = ((y - mean_y) ** 2).sum()
r2 = SSregression / SStotal
print (r2)
# Out:
# 0.5174025426948516
