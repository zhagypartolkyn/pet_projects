# %%
import numpy as np
import pandas as pd

waiting_times = np.array([6.22, 9.92, 9.04, 15.57, 15.33, 10.34, 11.19, 6.38, 7.22, 8.43, 10.34, 14.43, 14.32, 8, 8.6, 5.7, 6.3, 3.2, 17.16, 7.81, 8.09, 6.99, 12.7, 10.62, 9.94])

waiting_times.mean()
# Out:
# 9.753599999999999

# %%
df = pd.DataFrame(waiting_times)

print(df.std())
# Out:
# 0    3.518952
# dtype: float64

# %%
s = (200/30)**0.5
r = -5/s
r
# Out:
# -1.9364916731037085

# %%
from scipy import stats
import numpy as np
# Хи-квадрат тест
# Контингентная таблица для кофе/чая и пола
observed = np.array([[100, 30], [200, 20]])
chi2_stat, p_value_chi2 = stats.chi2_contingency(observed)[0:2]
chi2_stat, p_value_chi2
# Out:
# (11.93640734265734, 0.0005504752919243606)

# %%
H = np.array([[1, 0, 0, 3, 0], [3, 0, 2, 0, 0], [0, 2, 0, 0, 1], [0, 0, 0, -1, 1], [0, -3, 3, 0, 0]])
determinant = np.linalg.det(H)

# %%
determinant
# Out:
# 60.000000000000036

# %%
matris = np.array([[-1, 2, -4, 5], [2, -4, -3, -3], [-1, 4, 0, 4], [-2, 0, -16, 12]])
det = np.linalg.det(matris)
det
# Out:
# 0.0

# %%
#9
u = np.array([[-1, 2, -1, -2], [2, -4, 4, 0], [-4, -3, 0, -16], [5, -3, 4, 12]])
det = np.linalg.det(matris)
det
# Out:
# 0.0

# %%
n = []
for i in range(100, 999):
    if i%2 != 0:
        n.append(i)
print(len(n))
# Out:
# 449

# %%
#28
from scipy import stats
import numpy as np
scores = np.array([[58, 61, 55, 46]])
d_stat, p_value_ks = stats.kstest(scores, 'norm', args=(scores.mean(), scores.std()))
d_stat, p_value_ks
# Out:
# (array([0.70350995, 0.8574753 , 0.5       , 0.94559528]),
#  array([0.5929801 , 0.28504941, 1.        , 0.10880943]))

# %%
g = 0.575**0.5
g
# Out:
# 0.758287544405155
